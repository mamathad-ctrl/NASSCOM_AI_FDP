# %%
import os

# Get current working directory
print("Current Directory:", os.getcwd())

# List files and directories in current directory
print("Files and Folders:", os.listdir())

# Create a new folder
os.mkdir("demo_folder")  # Creates folder named 'demo_folder'

# Rename a folder
os.rename("demo_folder", "renamed_folder")

# Remove a folder (make sure it's empty)
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
import random
from datetime import datetime, timedelta
DEVICE_TYPES = ["Temperature", "Humidity", "Pressure"]

READING_RANGES = {
    "Temperature": (20.0, 40.0),
    "Humidity": (30.0, 90.0),
    "Pressure": (950.0, 1050.0)
}

# Sample locations
LOCATIONS = ["Room-A", "Room-B", "Lab-1", "Lab-2", "Warehouse"]

# Generate 100 sensor readings
raw_sensor_data = []

start_time = datetime.now()

for i in range(1, 101):
    timestamp = start_time + timedelta(seconds=i * 10)
    timestamp_str = timestamp.strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    min_val, max_val = READING_RANGES[device_type]
    value = round(random.uniform(min_val, max_val), 2)

    reading = (
        timestamp_str,
        device_id,
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---

# %%
#1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = [
    {
        'timestamp': reading[0],
        'device_id': reading[1],
        'location': reading[3],
        'temperature_celsius': reading[4]
    }
    for reading in raw_sensor_data
    if reading[2] == 'Temperature'  # Corrected from 'Temperature_Sensor' to 'Temperature'
]

# %%
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
unique_locations = {reading[3] for reading in raw_sensor_data}

# %%
unique_locations
# Out:
# {'Lab-1', 'Lab-2', 'Room-A', 'Room-B', 'Warehouse'}

# %%
# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.
# Create device_stats dictionary
device_stats = {}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    # Initialize with large/small values
    if device_type not in device_stats:
        device_stats[device_type] = (float('inf'), float('-inf'))

    current_min, current_max = device_stats[device_type]

    device_stats[device_type] = (
        min(current_min, value),
        max(current_max, value)
    )

# Display results
print(device_stats)
# Out:
# {'Humidity': (34.88, 90.0), 'Pressure': (955.67, 1045.52), 'Temperature': (20.07, 39.57)}

# %%
# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
sliced_readings_1=raw_sensor_data[10:21]
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---

# %%
print(sliced_readings_1)
# Out:
# [('2026-06-10 08:53:53', 'DEV011', 'Temperature', 'Lab-2', 31.2), ('2026-06-10 08:54:03', 'DEV012', 'Temperature', 'Lab-1', 32.19), ('2026-06-10 08:54:13', 'DEV013', 'Humidity', 'Warehouse', 70.22), ('2026-06-10 08:54:23', 'DEV014', 'Humidity', 'Room-B', 79.69), ('2026-06-10 08:54:33', 'DEV015', 'Temperature', 'Lab-1', 21.97), ('2026-06-10 08:54:43', 'DEV016', 'Humidity', 'Lab-1', 71.49), ('2026-06-10 08:54:53', 'DEV017', 'Humidity', 'Lab-2', 63.01), ('2026-06-10 08:55:03', 'DEV018', 'Temperature', 'Lab-1', 39.04), ('2026-06-10 08:55:13', 'DEV019', 'Humidity', 'Lab-1', 87.02), ('2026-06-10 08:55:23', 'DEV020', 'Pressure', 'Room-B', 971.1), ('2026-06-10 08:55:33', 'DEV021', 'Pressure', 'Warehouse', 1034.22)]

# %%
sliced_readings_2 = raw_sensor_data[::5]

# Display the result
print(sliced_readings_2)
# Out:
# [('2026-06-10 08:52:13', 'DEV001', 'Humidity', 'Warehouse', 78.73), ('2026-06-10 08:53:03', 'DEV006', 'Humidity', 'Room-B', 69.14), ('2026-06-10 08:53:53', 'DEV011', 'Temperature', 'Lab-2', 31.2), ('2026-06-10 08:54:43', 'DEV016', 'Humidity', 'Lab-1', 71.49), ('2026-06-10 08:55:33', 'DEV021', 'Pressure', 'Warehouse', 1034.22), ('2026-06-10 08:56:23', 'DEV026', 'Temperature', 'Warehouse', 29.26), ('2026-06-10 08:57:13', 'DEV031', 'Pressure', 'Room-A', 983.08), ('2026-06-10 08:58:03', 'DEV036', 'Humidity', 'Room-A', 40.59), ('2026-06-10 08:58:53', 'DEV041', 'Pressure', 'Room-A', 1014.29), ('2026-06-10 08:59:43', 'DEV046', 'Temperature', 'Warehouse', 26.71), ('2026-06-10 09:00:33', 'DEV051', 'Temperature', 'Room-B', 39.57), ('2026-06-10 09:01:23', 'DEV056', 'Humidity', 'Room-A', 77.61), ('2026-06-10 09:02:13', 'DEV061', 'Pressure', 'Warehouse', 975.88), ('2026-06-10 09:03:03', 'DEV066', 'Temperature', 'Room-A', 20.07), ('2026-06-10 09:03:53', 'DEV071', 'Temperature', 'Room-A', 36.54), ('2026-06-10 09:04:43', 'DEV076', 'Pressure', 'Warehouse', 1045.48), ('2026-06-10 09:05:33', 'DEV081', 'Temperature', 'Room-A', 29.56), ('2026-06-10 09:06:23', 'DEV086', 'Pressure', 'Lab-1', 971.93), ('2026-06-10 09:07:13', 'DEV091', 'Temperature', 'Room-B', 30.85), ('2026-06-10 09:08:03', 'DEV096', 'Pressure', 'Room-B', 987.55)]

# %%
# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
sample_string = "PythonProgrammingIsFun"

# Extract the substring "Programming"
substring_1 = sample_string[7:21]

# Extract the substring "nohtyP" (the reverse of "Python")
substring_2 = sample_string[:6][::-1]

# %%
print(substring_1)
print(substring_2)
# Out:
# rogrammingIsFu
# nohtyP

# %%
# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)
# Out:
# Pressure
# essure

# %%
# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(readings_list, target_location):
    return [reading for reading in readings_list if reading[3] == target_location]

# Example usage
location_readings = get_readings_by_location(raw_sensor_data, "Lab-1")

for reading in location_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
# ('2026-06-10 08:52:33', 'DEV003', 'Temperature', 'Lab-1', 20.37)
# ('2026-06-10 08:53:23', 'DEV008', 'Humidity', 'Lab-1', 90.0)
# ('2026-06-10 08:54:03', 'DEV012', 'Temperature', 'Lab-1', 32.19)
# ('2026-06-10 08:54:33', 'DEV015', 'Temperature', 'Lab-1', 21.97)
# ('2026-06-10 08:54:43', 'DEV016', 'Humidity', 'Lab-1', 71.49)
# ('2026-06-10 08:55:03', 'DEV018', 'Temperature', 'Lab-1', 39.04)
# ('2026-06-10 08:55:13', 'DEV019', 'Humidity', 'Lab-1', 87.02)
# ('2026-06-10 08:55:43', 'DEV022', 'Temperature', 'Lab-1', 38.19)
# ('2026-06-10 08:56:03', 'DEV024', 'Temperature', 'Lab-1', 28.17)
# ('2026-06-10 08:57:43', 'DEV034', 'Temperature', 'Lab-1', 37.72)
# ('2026-06-10 08:57:53', 'DEV035', 'Humidity', 'Lab-1', 89.61)
# ('2026-06-10 08:58:13', 'DEV037', 'Humidity', 'Lab-1', 89.28)
# ('2026-06-10 08:58:33', 'DEV039', 'Pressure', 'Lab-1', 1008.28)
# ('2026-06-10 08:59:13', 'DEV043', 'Temperature', 'Lab-1', 25.65)
# ('2026-06-10 09:00:03', 'DEV048', 'Humidity', 'Lab-1', 35.93)
# ('2026-06-10 09:00:43', 'DEV052', 'Temperature', 'Lab-1', 27.34)
# ('2026-06-10 09:00:53', 'DEV053', 'Pressure', 'Lab-1', 1027.33)
# ('2026-06-10 09:01:03', 'DEV054', 'Pressure', 'Lab-1', 971.45)
# ('2026-06-10 09:03:33', 'DEV069', 'Pressure', 'Lab-1', 978.11)
# ('2026-06-10 09:04:33', 'DEV075', 'Humidity', 'Lab-1', 42.75)
# ('2026-06-10 09:05:13', 'DEV079', 'Pressure', 'Lab-1', 955.67)
# ('2026-06-10 09:06:13', 'DEV085', 'Pressure', 'Lab-1', 1040.22)
# ('2026-06-10 09:06:23', 'DEV086', 'Pressure', 'Lab-1', 971.93)
# ('2026-06-10 09:07:53', 'DEV095', 'Temperature', 'Lab-1', 33.06)

# %%
# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
# Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if not temp_data_list:
        return 0.0

    total_temperature = sum(
        reading['temperature_celsius'] for reading in temp_data_list
    )

    return total_temperature / len(temp_data_list)

# Example usage
average_temp = calculate_average_temperature(temperature_readings)
print("Average Temperature:", average_temp)
# Out:
# Average Temperature: 0.0

# %%
# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

def generate_report_line(reading_dict):
    return "[{}] Device {} at {}: {}°C".format(
        reading_dict['timestamp'],
        reading_dict['device_id'],
        reading_dict['location'],
        reading_dict['temperature_celsius']
    )

# %%
# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")
import os

# 3.1 Use the os module to create a new directory named 'sensor_reports'
# in the current working directory, if it doesn't already exist.

reports_dir = 'sensor_reports'

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.

# %%
# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
random_values = [random.randint(100, 200) for _ in range(5)]

print("\nRandom Values:", random_values)
# Out:
# Duration of data collection: 0 days, 0 hours, 16 minutes.
#
# Random Values: [188, 109, 126, 150, 188]

# %%
report_file = os.path.join(reports_dir, "temperature_report.txt")

with open(report_file, "w") as file:
    for reading in temperature_readings:
        file.write(generate_report_line(reading) + "\n")

print(f"\nTemperature report written to '{report_file}'.")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'.

# %%
# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
report_file = os.path.join(reports_dir, "temperature_report.txt")

with open(report_file, "r") as file:
    read_report_lines = [line.strip() for line in file]

print("\nFirst 3 lines of the report:")

for line in read_report_lines[:3]:
    print(line)
# Out:
# First 3 lines of the report:
# [2026-06-10 08:52:33] Device DEV003 at Lab-1: 20.37°C
# [2026-06-10 08:52:43] Device DEV004 at Lab-2: 29.47°C
# [2026-06-10 08:53:53] Device DEV011 at Lab-2: 31.2°C
